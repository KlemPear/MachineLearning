# %% [markdown]
# # Classification with Tensorflow
#
# let's build a classifier for tweet sentiment analysis using tensorflow.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import roc_auc_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.optimizers import Adam

print(tf.__version__)
# Out:
# 2.11.0

# %% [markdown]
# Let's import our tweet dataset, and make it only positive or negative tweets, no neutral

# %%
df = pd.read_csv('../datasets/tweets/AirlineTweets.csv')
df = df[['airline_sentiment', 'text']]
df = df[df['airline_sentiment'] != 'neutral'].copy()
target_map = {'positive': 1, 'negative': 0}
df['label'] = df['airline_sentiment'].map(target_map)
df.head()
# Out:
#   airline_sentiment                                               text  label
# 1          positive  @VirginAmerica plus you've added commercials t...      1
# 3          negative  @VirginAmerica it's really aggressive to blast...      0
# 4          negative  @VirginAmerica and it's a really big bad thing...      0
# 5          negative  @VirginAmerica seriously would pay $30 a fligh...      0
# 6          positive  @VirginAmerica yes, nearly every time I fly VX...      1

# %% [markdown]
# Now that our dataset it preprocessed, let's split it in training and test set, and vectorize the text using TD-IDF

# %%
max_features = 2000
df_train, df_test = train_test_split(df, random_state=42)
vectorizer = TfidfVectorizer(max_features=max_features)
X_train = vectorizer.fit_transform(df_train['text'])
X_test = vectorizer.transform(df_test['text'])

# data must not be sparse matrix before passing into tensorflow
X_train = X_train.toarray()
X_test = X_test.toarray()

Y_train = np.array(df_train['label'])
Y_test = np.array(df_test['label'])

# %%
print('X_train: ', X_train.shape)
print('Y_train: ', Y_train.shape)
# Out:
# X_train:  (8655, 2000)
# Y_train:  (8655,)

# %% [markdown]
# At this point we have our dataset fully ready. Now let's build our neural network.

# %%
# input dimensions
D = X_train.shape[1]

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1, input_shape=(D,)),
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 2001
#
# =================================================================
# Total params: 2,001
# Trainable params: 2,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
  loss=BinaryCrossentropy(from_logits=True),
  optimizer=Adam(learning_rate=0.01),
  metrics=[tf.keras.metrics.BinaryAccuracy()]
)

# %% [markdown]
# Now let's train the model

# %%
r = model.fit(
  X_train, Y_train,
  validation_data=(X_test, Y_test),
  epochs=40,
  batch_size=256,
)
# Out:
# Epoch 1/40
# 2023-05-12 00:00:12.043241: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 34/34 [==============================] - 0s 4ms/step - loss: 0.5504 - binary_accuracy: 0.7920 - val_loss: 0.4459 - val_binary_accuracy: 0.8049
# Epoch 2/40
# 34/34 [==============================] - 0s 2ms/step - loss: 0.4223 - binary_accuracy: 0.7920 - val_loss: 0.3846 - val_binary_accuracy: 0.8053
# Epoch 3/40
# 34/34 [==============================] - 0s 2ms/step - loss: 0.3742 - binary_accuracy: 0.7963 - val_loss: 0.3507 - val_binary_accuracy: 0.8181
# Epoch 4/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.3394 - binary_accuracy: 0.8069 - val_loss: 0.3244 - val_binary_accuracy: 0.8288
# Epoch 5/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.3116 - binary_accuracy: 0.8259 - val_loss: 0.3037 - val_binary_accuracy: 0.8406
# Epoch 6/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.2891 - binary_accuracy: 0.8422 - val_loss: 0.2872 - val_binary_accuracy: 0.8527
# Epoch 7/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.2704 - binary_accuracy: 0.8545 - val_loss: 0.2738 - val_binary_accuracy: 0.8642
# Epoch 8/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.2548 - binary_accuracy: 0.8655 - val_loss: 0.2624 - val_binary_accuracy: 0.8732
# Epoch 9/40
# 34/34 [==============================] - 0s 2ms/step - loss: 0.2415 - binary_accuracy: 0.8769 - val_loss: 0.2531 - val_binary_accuracy: 0.8818
# Epoch 10/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.2301 - binary_accuracy: 0.8857 - val_loss: 0.2451 - val_binary_accuracy: 0.8877
# Epoch 11/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.2201 - binary_accuracy: 0.8927 - val_loss: 0.2383 - val_binary_accuracy: 0.8971
# Epoch 12/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.2113 - binary_accuracy: 0.8981 - val_loss: 0.2324 - val_binary_accuracy: 0.9009
# Epoch 13/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.2036 - binary_accuracy: 0.9035 - val_loss: 0.2274 - val_binary_accuracy: 0.9030
# Epoch 14/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1965 - binary_accuracy: 0.9086 - val_loss: 0.2230 - val_binary_accuracy: 0.9068
# Epoch 15/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1902 - binary_accuracy: 0.9120 - val_loss: 0.2193 - val_binary_accuracy: 0.9075
# Epoch 16/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1844 - binary_accuracy: 0.9153 - val_loss: 0.2158 - val_binary_accuracy: 0.9092
# Epoch 17/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1792 - binary_accuracy: 0.9182 - val_loss: 0.2128 - val_binary_accuracy: 0.9106
# Epoch 18/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1744 - binary_accuracy: 0.9224 - val_loss: 0.2103 - val_binary_accuracy: 0.9120
# Epoch 19/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1699 - binary_accuracy: 0.9254 - val_loss: 0.2079 - val_binary_accuracy: 0.9130
# Epoch 20/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1659 - binary_accuracy: 0.9266 - val_loss: 0.2058 - val_binary_accuracy: 0.9151
# Epoch 21/40
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1620 - binary_accuracy: 0.9303 - val_loss: 0.2040 - val_binary_accuracy: 0.9158
# Epoch 22/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1584 - binary_accuracy: 0.9307 - val_loss: 0.2023 - val_binary_accuracy: 0.9155
# Epoch 23/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1550 - binary_accuracy: 0.9340 - val_loss: 0.2008 - val_binary_accuracy: 0.9168
# Epoch 24/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1519 - binary_accuracy: 0.9353 - val_loss: 0.1995 - val_binary_accuracy: 0.9179
# Epoch 25/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1489 - binary_accuracy: 0.9380 - val_loss: 0.1983 - val_binary_accuracy: 0.9189
# Epoch 26/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1461 - binary_accuracy: 0.9384 - val_loss: 0.1973 - val_binary_accuracy: 0.9200
# Epoch 27/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1434 - binary_accuracy: 0.9393 - val_loss: 0.1963 - val_binary_accuracy: 0.9203
# Epoch 28/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1409 - binary_accuracy: 0.9413 - val_loss: 0.1956 - val_binary_accuracy: 0.9200
# Epoch 29/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1385 - binary_accuracy: 0.9419 - val_loss: 0.1949 - val_binary_accuracy: 0.9203
# Epoch 30/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1362 - binary_accuracy: 0.9430 - val_loss: 0.1942 - val_binary_accuracy: 0.9207
# Epoch 31/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1341 - binary_accuracy: 0.9450 - val_loss: 0.1936 - val_binary_accuracy: 0.9210
# Epoch 32/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1320 - binary_accuracy: 0.9445 - val_loss: 0.1930 - val_binary_accuracy: 0.9207
# Epoch 33/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1300 - binary_accuracy: 0.9455 - val_loss: 0.1926 - val_binary_accuracy: 0.9200
# Epoch 34/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1281 - binary_accuracy: 0.9474 - val_loss: 0.1923 - val_binary_accuracy: 0.9207
# Epoch 35/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1262 - binary_accuracy: 0.9478 - val_loss: 0.1920 - val_binary_accuracy: 0.9207
# Epoch 36/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1246 - binary_accuracy: 0.9482 - val_loss: 0.1918 - val_binary_accuracy: 0.9207
# Epoch 37/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1229 - binary_accuracy: 0.9495 - val_loss: 0.1916 - val_binary_accuracy: 0.9203
# Epoch 38/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1213 - binary_accuracy: 0.9509 - val_loss: 0.1914 - val_binary_accuracy: 0.9193
# Epoch 39/40
# 34/34 [==============================] - 0s 1ms/step - loss: 0.1197 - binary_accuracy: 0.9512 - val_loss: 0.1913 - val_binary_accuracy: 0.9207
# Epoch 40/40
# 34/34 [==============================] - 0s 2ms/step - loss: 0.1181 - binary_accuracy: 0.9523 - val_loss: 0.1912 - val_binary_accuracy: 0.9203

# %%
# Plot loss per iteration
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend();

# %%
# Plot accuracy per iteration
plt.plot(r.history['binary_accuracy'], label='train acc')
plt.plot(r.history['val_binary_accuracy'], label='val acc')
plt.legend();

# %%
p = model.predict(X_train)
print(p)
# Out:
# 271/271 [==============================] - 0s 338us/step
# [[ 1.6837975]
#  [-4.131456 ]
#  [ 0.6547003]
#  ...
#  [ 1.359266 ]
#  [-2.7364779]
#  [-3.619324 ]]

# %%
P_train = ((model.predict(X_train) > 0) * 1.0).flatten()
P_test = ((model.predict(X_test) > 0) * 1.0).flatten()
# Out:
# 271/271 [==============================] - 0s 301us/step
# 91/91 [==============================] - 0s 328us/step

# %%
P_train
# Out:
# array([1., 0., 1., ..., 1., 0., 0.])

# %%
cm_train = confusion_matrix(Y_train, P_train, normalize='true')
disp_train = ConfusionMatrixDisplay(confusion_matrix=cm_train, display_labels=['negative', 'positive'])
disp_train.plot()
cm_test = confusion_matrix(Y_test, P_test, normalize='true')
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=['negative', 'positive'])
disp_test.plot()

# %% [markdown]
# # Multi-Class Text Classifier with TensorFlow

# %%
df = pd.read_csv('../datasets/bbc/bbc_text_cls.csv')

# %%
# map classes to integers from 0...K-1
df['targets'] = df['labels'].astype("category").cat.codes

# %%
df.head()
# Out:
#                                                 text    labels  targets
# 0  Ad sales boost Time Warner profit\n\nQuarterly...  business        0
# 1  Dollar gains on Greenspan speech\n\nThe dollar...  business        0
# 2  Yukos unit buyer faces loan claim\n\nThe owner...  business        0
# 3  High fuel prices hit BA's profits\n\nBritish A...  business        0
# 4  Pernod takeover talk lifts Domecq\n\nShares in...  business        0

# %%
# split our dataset
df_train, df_test = train_test_split(df, test_size=0.2)

# %%
vectorizer = TfidfVectorizer(stop_words='english')
Xtrain = vectorizer.fit_transform(df_train['text'])
Xtest = vectorizer.transform(df_test['text'])

# %%
# data must not be sparse matrix before passing into tensorflow
Xtrain = Xtrain.toarray()
Xtest = Xtest.toarray()

# %%
Ytrain = df_train['targets']
Ytest = df_test['targets']

# %%
# input dimension
D = Xtrain.shape[1]
# number of categories
K = df['targets'].max() + 1

# %%
# Build a ANN model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, input_shape=(D,), activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(K),
])

model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 32)                843456
#
#  dense_20 (Dense)            (None, 32)                1056
#
#  dense_21 (Dense)            (None, 5)                 165
#
# =================================================================
# Total params: 844,677
# Trainable params: 844,677
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  optimizer='adam',
  metrics=['accuracy']
)

# %%
r = model.fit(
  Xtrain, Ytrain,
  validation_data=(Xtest, Ytest),
  epochs=25,
  batch_size=128,
)
# Out:
# Epoch 1/25
# 14/14 [==============================] - 0s 11ms/step - loss: 1.5729 - accuracy: 0.6612 - val_loss: 1.5062 - val_accuracy: 0.9281
# Epoch 2/25
# 14/14 [==============================] - 0s 6ms/step - loss: 1.4062 - accuracy: 0.9404 - val_loss: 1.3175 - val_accuracy: 0.9348
# Epoch 3/25
# 14/14 [==============================] - 0s 6ms/step - loss: 1.1499 - accuracy: 0.9730 - val_loss: 1.0643 - val_accuracy: 0.9506
# Epoch 4/25
# 14/14 [==============================] - 0s 6ms/step - loss: 0.8401 - accuracy: 0.9843 - val_loss: 0.7861 - val_accuracy: 0.9461
# Epoch 5/25
# 14/14 [==============================] - 0s 6ms/step - loss: 0.5450 - accuracy: 0.9927 - val_loss: 0.5468 - val_accuracy: 0.9618
# Epoch 6/25
# 14/14 [==============================] - 0s 6ms/step - loss: 0.3253 - accuracy: 0.9989 - val_loss: 0.3776 - val_accuracy: 0.9753
# Epoch 7/25
# 14/14 [==============================] - 0s 6ms/step - loss: 0.1879 - accuracy: 0.9989 - val_loss: 0.2719 - val_accuracy: 0.9798
# Epoch 8/25
# 14/14 [==============================] - 0s 8ms/step - loss: 0.1116 - accuracy: 0.9994 - val_loss: 0.2103 - val_accuracy: 0.9820
# Epoch 9/25
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0712 - accuracy: 0.9994 - val_loss: 0.1735 - val_accuracy: 0.9820
# Epoch 10/25
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0493 - accuracy: 1.0000 - val_loss: 0.1496 - val_accuracy: 0.9820
# Epoch 11/25
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0360 - accuracy: 1.0000 - val_loss: 0.1337 - val_accuracy: 0.9820
# Epoch 12/25
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0274 - accuracy: 1.0000 - val_loss: 0.1219 - val_accuracy: 0.9843
# Epoch 13/25
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0217 - accuracy: 1.0000 - val_loss: 0.1132 - val_accuracy: 0.9843
# Epoch 14/25
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.1064 - val_accuracy: 0.9843
# Epoch 15/25
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.1009 - val_accuracy: 0.9843
# Epoch 16/25
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0961 - val_accuracy: 0.9843
# Epoch 17/25
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0923 - val_accuracy: 0.9820
# Epoch 18/25
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 0.0892 - val_accuracy: 0.9820
# Epoch 19/25
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0864 - val_accuracy: 0.9820
# Epoch 20/25
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0839 - val_accuracy: 0.9843
# Epoch 21/25
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 0.9843
# Epoch 22/25
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9843
# Epoch 23/25
# 14/14 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0780 - val_accuracy: 0.9843
# Epoch 24/25
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0765 - val_accuracy: 0.9843
# Epoch 25/25
# 14/14 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0751 - val_accuracy: 0.9843

# %%
# Plot loss per iteration
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='val loss')
plt.legend();

# %%
# Plot accuracy per iteration
plt.plot(r.history['accuracy'], label='train acc')
plt.plot(r.history['val_accuracy'], label='val acc')
plt.legend();
